# %% [markdown]
# # PANDAS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Définir un objet Series comprenant la population de 4 pays puis afficher les pays ayant une population > 50’000’000.

# %%
ser_pop=pd.Series(data=[70,8,300,1200],index=["France","Suisse","USA","Chine"],dtype=int)

# %% [markdown]
# Manipulation d'une Series

# %%
ser_pop["Suisse"]
# Out:
# 8

# %%
ser_pop.iloc[1:3]
# Out:
# Suisse      8
# USA       300
# dtype: int32

# %%
ser_pop[["Suisse","USA"]]
# Out:
# Suisse      8
# USA       300
# dtype: int32

# %%
ser_pop[ser_pop>50]
# Out:
# France      70
# USA        300
# Chine     1200
# dtype: int32

# %%
# opérateur de conditions | &
ser_pop[(ser_pop<50)|(ser_pop>300)]
# Out:
# Suisse       8
# Chine     1200
# dtype: int32

# %% [markdown]
# Définir les noms de l’objet et de la colonne des pays pour la Series précédente

# %%
ser_pop.name="Populations"
ser_pop.index.name="Pays"
ser_pop
# Out:
# Pays
# France      70
# Suisse       8
# USA        300
# Chine     1200
# Name: Populations, dtype: int32

# %% [markdown]
# Créez un objet Series et ajoutez des dates partant du 3 octobre 2017 par jour jusqu’à aujourd’hui.

# %%
dates=pd.date_range(start="2017-10-03",end=pd.datetime.today(),freq="D")
ser_dates=pd.Series(np.random.randn(dates.size),index=dates)

# %%
ser_dates.plot()

# %%
dates.weekday_name
# Out:
# Index(['Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday',
#        'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        ...
#        'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Wednesday', 'Thursday', 'Friday', 'Saturday'],
#       dtype='object', length=390)

# %% [markdown]
# Récupérez les données de Wikipédia sur les résultats de NBA et obtenir les statistiques descriptives pour les variables quantitatives.
# On utilisera plutôt Chrome ou Firefox pour ce type de tâches (éviter IE)

# %%
import webbrowser
url='https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records'
webbrowser.open(url)
# Out:
# True

# %%
frame_nba=pd.read_clipboard()
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)

# %%
frame_nba
# Out:
#     Rank                    Team    Won   Lost   Pct. First NBA season  \
# 0      1       San Antonio Spurs  2,114  1,282  0.622          1976–77
# 1      2      Los Angeles Lakers  3,296  2,237  0.596          1948–49
# 2      3          Boston Celtics  3,329  2,313  0.590          1946–47
# 3      4   Oklahoma City Thunder  2,234  1,900  0.540          1967–68
# 4      5               Utah Jazz  1,914  1,646  0.538          1974–75
# 5      6  Portland Trail Blazers  2,081  1,807  0.535          1970–71
# 6      7            Phoenix Suns  2,167  1,885  0.535          1968–69
# 7      8         Houston Rockets  2,172  1,962  0.525          1967–68
# 8      9              Miami Heat  1,255  1,157  0.520          1988–89
# 9     10           Chicago Bulls  2,183  2,032  0.518          1966–67
# 10    11      Philadelphia 76ers  2,806  2,662  0.513          1949–50
# 11    12         Milwaukee Bucks  2,069  1,983  0.511          1968–69
# ...

# %% [markdown]
# Importez le fichier listing.csv depuis Python.

# %%
frame_listing=pd.read_csv("https://www.stat4decision.com/listings.csv.gz")
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3018: DtypeWarning: Columns (43,61,62) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# on affiche les 5 premières lignes
frame_listing.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3109  https://www.airbnb.com/rooms/3109  20180306174610   2018-03-09
# 1  5396  https://www.airbnb.com/rooms/5396  20180306174610   2018-03-07
# 2  7397  https://www.airbnb.com/rooms/7397  20180306174610   2018-03-09
# 3  8522  https://www.airbnb.com/rooms/8522  20180306174610   2018-03-09
# 4  9342  https://www.airbnb.com/rooms/9342  20180306174610   2018-03-09
#
#                                name  \
# 0                      zen and calm
# 1    Explore the heart of old Paris
# 2  LA VERRERIE - MARAIS- 2/4 PEOPLE
# 3           GREAT FLAT w/ CITY VIEW
# 4   STAY ON A BARGE IN PARIS CENTER
#
#                                              summary  \
# 0  Appartement très calme de 50M2 Belle lumière D...
# 1  Cozy, well-appointed and graciously designed s...
# 2           VERY CONVENIENT WITH THE BEST LOCATION !
# 3                                                NaN
# ...

# %%
# on affiche la forme du dataframe
frame_listing.shape
# Out:
# (59945, 96)

# %%
# on affiche la première ligne
frame_listing.iloc[0]
# Out:
# id                                                                               3109
# listing_url                                         https://www.airbnb.com/rooms/3109
# scrape_id                                                              20180306174610
# last_scraped                                                               2018-03-09
# name                                                                     zen and calm
# summary                             Appartement très calme de 50M2 Belle lumière D...
# space                                                I bedroom appartment in Paris 14
# description                                          I bedroom appartment in Paris 14
# experiences_offered                                                              none
# neighborhood_overview                                                             NaN
# notes                                                                             NaN
# ...

# %%
# on affiche des informations sur les colonnes
frame_listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59945 entries, 0 to 59944
# Data columns (total 96 columns):
# id                                  59945 non-null int64
# listing_url                         59945 non-null object
# scrape_id                           59945 non-null int64
# last_scraped                        59945 non-null object
# name                                59856 non-null object
# summary                             58048 non-null object
# space                               40358 non-null object
# description                         59913 non-null object
# experiences_offered                 59945 non-null object
# neighborhood_overview               35255 non-null object
# notes                               17913 non-null object
# transit                             37655 non-null object
# access                              29032 non-null object
# interaction                         27592 non-null object
# ...

# %%
# pour accéder à une colonne , on peut utiliser :
frame_listing.price
frame_listing["price"]
# Out:
# 0         $59.00
# 1         $93.00
# 2        $110.00
# 3         $90.00
# 4        $371.00
# 5         $70.00
# 6        $135.00
# 7        $105.00
# 8         $75.00
# 9         $90.00
# 10        $65.00
# 11       $157.00
# 12        $71.00
# 13       $100.00
# 14        $70.00
# 15        $75.00
# 16       $100.00
# 17        $79.00
# 18        $60.00
# 19        $49.00
# 20        $50.00
# 21        $89.00
# 22       $110.00
# 23       $125.00
# 24       $149.00
# 25        $55.00
# 26        $59.00
# 27       $100.00
# 28        $35.00
# 29       $110.00
#           ...
# 59915    $110.00
# 59916     $65.00
# 59917    $100.00
# 59918     $70.00
# 59919    $138.00
# 59920    $500.00
# 59921    $300.00
# 59922     $61.00
# 59923     $83.00
# 59924     $39.00
# 59925     $95.00
# 59926    $255.00
# 59927     $75.00
# 59928     $45.00
# 59929    $999.00
# 59930     $85.00
# 59931     $70.00
# 59932    $170.00
# 59933    $130.00
# 59934     $58.00
# 59935     $50.00
# ...

# %% [markdown]
# Importez un tableau en html depuis la page <br>
# http://www.fdic.gov/bank/individual/failed/banklist.html

# %%
page=pd.read_html("http://www.fdic.gov/bank/individual/failed/banklist.html")

# %%
type(page)
# Out:
# list

# %%
page[0]
# Out:
#                                              Bank Name                City  \
# 0                  Washington Federal Bank for Savings             Chicago
# 1      The Farmers and Merchants State Bank of Argonia             Argonia
# 2                                  Fayette County Bank          Saint Elmo
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 4                                       First NBC Bank         New Orleans
# 5                                        Proficio Bank  Cottonwood Heights
# 6                        Seaway Bank and Trust Company             Chicago
# 7                               Harvest Community Bank          Pennsville
# 8                                          Allied Bank            Mulberry
# 9                         The Woodbury Banking Company            Woodbury
# 10                              First CornerStone Bank     King of Prussia
# ...

# %% [markdown]
# Récupérer les données NBA

# %%
page_nba=pd.read_html("https://en.wikipedia.org/wiki/List_of_all-time_NBA_win-loss_records",
                     header="infer")

# %%
len(page_nba)
# Out:
# 11

# %%
page_nba[1]
# Out:
#     Rank                    Team   Won  Lost   Pct. First NBA season  \
# 0      1       San Antonio Spurs  2114  1282  0.622          1976–77
# 1      2      Los Angeles Lakers  3296  2237  0.596          1948–49
# 2      3          Boston Celtics  3329  2313  0.590          1946–47
# 3      4   Oklahoma City Thunder  2234  1900  0.540          1967–68
# 4      5               Utah Jazz  1914  1646  0.538          1974–75
# 5      6  Portland Trail Blazers  2081  1807  0.535          1970–71
# 6      7            Phoenix Suns  2167  1885  0.535          1968–69
# 7      8         Houston Rockets  2172  1962  0.525          1967–68
# 8      9              Miami Heat  1255  1157  0.520          1988–89
# 9     10           Chicago Bulls  2183  2032  0.518          1966–67
# 10    11      Philadelphia 76ers  2806  2662  0.513          1949–50
# 11    12         Milwaukee Bucks  2069  1983  0.511          1968–69
# 12    13        Dallas Mavericks  1539  1529  0.502          1980–81
# ...

# %% [markdown]
# Importez un fichier Excel depuis python. On utilisera excel-data.xlsx et Presidentielle_2017_Resultats_Communes_Tour_1.xls
#
# On a deux approches :
# - avec pd.read_excel en connaissant la feuille qui nous intéresse
# - avec pd.ExcelFile afin de créer un objet dans lequel on pourra avoir toutes les feuilles

# %%
frame_excel=pd.read_excel("../data/credit2.xlsx")

# %%
frame_excel["Gender"]=frame_excel["Gender"].map({"F":"Femme","M":"Homme"})
frame_excel.to_excel("../data/credit2_bis.xlsx")

# %%
fichier_excel=pd.ExcelFile("../data/credit2_bis.xlsx")

# %%
frame_excel2=fichier_excel.parse('Sheet1')

# %%
frame_excel2
# Out:
#       Age Gender Marital_Status  Age_Youngest_Child  \
# 0      40  Femme              S                  11
# 1      47  Homme              M                  13
# 2      35  Femme              U                   1
# 3      45  Homme              U                  15
# 4      13  Femme              S                   0
# 5      45  Femme              S                  14
# 6      40  Homme              U                   7
# 7      36  Femme              S                   7
# 8      26  Homme              S                   0
# 9      33  Homme              S                   2
# 10     64  Femme              S                  31
# 11     43  Femme              M                  14
# 12     37  Homme              U                  10
# 13     35  Femme              U                   6
# 14     59  Femme              M                  29
# 15     15  Femme              S                   0
# 16     52  Femme              M                  21
# ...

# %% [markdown]
# On peut ajouter une feuille à un fichier Excel avec :

# %%
from openpyxl import load_workbook
book = load_workbook('../data/credit2_bis.xlsx')
writer = pd.ExcelWriter('../data/credit2.xlsx', engine='openpyxl')
writer.book = book
frame_listing.iloc[:1000,:10].to_excel(writer,'sheet111',startrow=0,startcol=2)
writer.save()
writer.close()

# %% [markdown]
# Importez la base de données SQLite salaries et récupérez la table Salaries dans un DataFrame

# %%
from sqlalchemy import create_engine

# %%
con=create_engine("sqlite:///../data/Salaries.sqlite")

# %%
con.table_names()
# Out:
# ['Salaries']

# %%
frame_salaries=pd.read_sql_query("select * from Salaries",con)

# %%
frame_salaries.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#   BasePay OvertimePay OtherPay Benefits   TotalPay  TotalPayBenefits  Year  \
# 0  167411           0   400184           567595.43         567595.43  2011
# 1  155966      245132   137811           538909.28         538909.28  2011
# 2  212739      106088  16452.6           335279.91         335279.91  2011
# 3   77916     56120.7   198307           332343.61         332343.61  2011
# 4  134402        9737   182235           326373.19         326373.19  2011
#
#   Notes         Agency Status
# 0        San Francisco
# ...

# %% [markdown]
# Il s'agit des salariés de la ville de San Francisco et de leurs salaires

# %%
# on veut créer une colonne de prix sur les données AirBnB
frame_listing["prix"]=pd.to_numeric(frame_listing["price"].str.replace("$","").str.replace(",",""))

# %%
frame_chers=frame_listing[frame_listing["prix"]>1000].drop(["price"],axis=1)

# %%
frame_chers.sort_values("prix",ascending=False).head()
# Out:
#              id                            listing_url       scrape_id  \
# 18597   7225849   https://www.airbnb.com/rooms/7225849  20180306174610
# 7561    2995800   https://www.airbnb.com/rooms/2995800  20180306174610
# 184       68905     https://www.airbnb.com/rooms/68905  20180306174610
# 23650   9442661   https://www.airbnb.com/rooms/9442661  20180306174610
# 51714  20856017  https://www.airbnb.com/rooms/20856017  20180306174610
#
#       last_scraped                                  name  \
# 18597   2018-03-07        Artistic apartment, Montmartre
# 7561    2018-03-09        3 bedrooms flat in Montmartre!
# 184     2018-03-09       Private quiet little town house
# 23650   2018-03-10      Lively studette in 19th district
# 51714   2018-03-08  Le Louvre Factory, lieu évènementiel
#
#                                                  summary  \
# 18597  2 bedrooms on different floors in this Duplex....
# 7561    Typical parisian flat in Montmartre near Sacr...
# ...

# %%
frame_chers.columns.sort_values()
# Out:
# Index(['access', 'accommodates', 'amenities', 'availability_30',
#        'availability_365', 'availability_60', 'availability_90', 'bathrooms',
#        'bed_type', 'bedrooms', 'beds', 'calculated_host_listings_count',
#        'calendar_last_scraped', 'calendar_updated', 'cancellation_policy',
#        'city', 'cleaning_fee', 'country', 'country_code', 'description',
#        'experiences_offered', 'extra_people', 'first_review',
#        'guests_included', 'has_availability', 'host_about',
#        'host_acceptance_rate', 'host_has_profile_pic', 'host_id',
#        'host_identity_verified', 'host_is_superhost', 'host_listings_count',
#        'host_location', 'host_name', 'host_neighbourhood', 'host_picture_url',
#        'host_response_rate', 'host_response_time', 'host_since',
#        'host_thumbnail_url', 'host_total_listings_count', 'host_url',
#        'host_verifications', 'house_rules', 'id', 'instant_bookable',
# ...

# %%
frame_chers.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  7.000000e+01  7.000000e+01            0.0         0.0             0.0
# mean   1.431166e+07  2.018031e+13            NaN         NaN             NaN
# std    6.936317e+06  0.000000e+00            NaN         NaN             NaN
# min    6.890500e+04  2.018031e+13            NaN         NaN             NaN
# 25%    8.760483e+06  2.018031e+13            NaN         NaN             NaN
# 50%    1.565091e+07  2.018031e+13            NaN         NaN             NaN
# 75%    1.994298e+07  2.018031e+13            NaN         NaN             NaN
# max    2.317231e+07  2.018031e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  7.000000e+01                   0.0            70.000000
# mean   4.250114e+07                   NaN            56.042857
# std    5.231858e+07                   NaN           119.396725
# ...

# %%
frame_chers["prix"].agg(["mean","median","var"])
# Out:
# mean      1.942443e+03
# median    1.400000e+03
# var       2.702609e+06
# Name: prix, dtype: float64

# %% [markdown]
# Joindre les deux dataframes de crédits

# %%
credit1=pd.read_table("../data/credit1.txt")
credit2=pd.read_excel("../data/credit2.xlsx")

# %%
credit_total=pd.merge(credit1,credit2,how="inner",on="Customer_ID")

# %%
credit_total.head()
# Out:
#    Months_as_a_Customer  Number_of_Products  RFM_Score  \
# 0                    24                   3         10
# 1                    12                   2         12
# 2                    36                   0          0
# 3                     0                   0          0
# 4                    48                   0          0
#
#    Average_Balance_Feed_Index  Number_of_Transactions  \
# 0                         229                       2
# 1                           8                       1
# 2                           0                       0
# 3                           0                       0
# 4                           0                       0
#
#    Personal_Debt_to_Equity_Ratio  Months_Current_Account  \
# 0                             40                      13
# 1                             47                       5
# 2                             35                      31
# 3                             45                      -3
# ...

# %% [markdown]
# ## GROUPBY

# %% [markdown]
# - Données sur les salaires
#
# - On utilise le groupby() pour rassembler les types d’emploi
#
# - Et on calcule des statistiques pour chaque type
#
# On peut utiliser la fonction .agg() avec par exemple ‘mean’ comme paramètre
#
# On utilise aussi fréquemment la fonction apply() combinée à une fonction lambda

# %%
credit_total.groupby(["Marital_Status","Gender"])["Income"].mean()
# Out:
# Marital_Status  Gender
# M               Femme     49476.908730
#                 Homme     52838.879562
# S               Femme     49980.352342
#                 Homme     48028.174274
# U               Femme     50429.883333
#                 Homme     51341.482759
# Name: Income, dtype: float64

# %%
credit_total.groupby(["Marital_Status","Gender"])[["Income","Age"]].apply(lambda x:x.max()-x.min())
# Out:
#                        Income  Age
# Marital_Status Gender
# M              Femme    60208   49
#                Homme    56558   55
# S              Femme    48868   69
#                Homme    62329   70
# U              Femme    54198   56
#                Homme    58881   55

# %%
credit_total.pivot_table(values="Income",index="Marital_Status",columns="Gender",aggfunc=["mean","median"])
# Out:
#                         mean               median
# Gender                 Femme         Homme  Femme  Homme
# Marital_Status
# M               49476.908730  52838.879562  49609  52217
# S               49980.352342  48028.174274  49921  47843
# U               50429.883333  51341.482759  49518  51008

# %%
np.average(creadit_total["Age"],weights=creadit_total["Income"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-3a9cffb0420f> in <module>
# ----> 1 np.average(creadit_total["Age"],weights=creadit_total["Income"])
#
# NameError: name 'creadit_total' is not defined

# %% [markdown]
# ### Un graphique

# %%
frame_listing=frame_listing[frame_listing.prix<300]
plt.scatter(frame_listing.longitude,frame_listing.latitude, s=1,c=frame_listing.prix)
plt.colorbar()
